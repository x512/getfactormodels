# %%
import getfactormodels
getfactormodels.__version__
# Out:
# '0.0.7'

# %% [markdown]
# ### Quick start
# After installation, the easiest way to use getfactormodels is the get_factors() module.
#
# Specify a model, frequency (default: m), and optionally start date, end date, and output file:

# %%
import getfactormodels # import

#call get_factors() with a model and frequency parameter:
df = getfactormodels.get_factors(model="carhart", frequency='m')

print(df)
# Out:
# INFO:getfactormodels.models.fama_french.FamaFrenchFactors:Downloading data from: https://mba.tuck.dartmouth.edu/pages/faculty/ken.french/ftp/F-F_Research_Data_Factors_CSV.zip
#             Mkt-RF     SMB     HML      RF     MOM
# date
# 1926-07-31  0.0289 -0.0255 -0.0239  0.0022     NaN
# 1926-08-31  0.0264 -0.0114  0.0381  0.0025     NaN
# 1926-09-30  0.0038 -0.0136  0.0005  0.0023     NaN
# 1926-10-31 -0.0327 -0.0014  0.0082  0.0032     NaN
# 1926-11-30  0.0254 -0.0011 -0.0061  0.0031     NaN
# ...            ...     ...     ...     ...     ...
# 2025-06-30  0.0486  0.0083 -0.0160  0.0034 -0.0264
# 2025-07-31  0.0198  0.0027 -0.0127  0.0034 -0.0096
# 2025-08-31  0.0184  0.0387  0.0442  0.0038 -0.0354
# 2025-09-30  0.0339 -0.0185 -0.0105  0.0033  0.0463
# 2025-10-31  0.0195 -0.0055 -0.0310  0.0037  0.0031
#
# [1192 rows x 5 columns]

# %% [markdown]
# Similarly, in the CLI just call `getfactormodels` with the `--model`, `m` and `--frequency`, `-f` flags.

# %%
# %%bash
# # Get monthly Mispricing factors:
# getfactormodels --model misp --frequency d --start 1990-01-01 --end 1999-12-31
#
# #By default data is saved to `~/`.
# #(TODO: FIX THIS)
# Out:
# INFO:getfactormodels.models.mispricing.MispricingFactors:Downloading data from: https://finance.wharton.upenn.edu/~stambaug/M4.csv
# File exists: misp_m_None_None.csv - overwriting...
# File saved to: /home/x512/misp_m_None_None.csv
#
#             Mkt-RF    SMB_SY      MGMT      PERF      RF
# date
# 1963-01-31  0.0493  0.024818  0.021349 -0.022751  0.0025
# 1963-02-28 -0.0238  0.018096  0.010961  0.000874  0.0023
# 1963-03-31  0.0308 -0.008183  0.005890  0.023281  0.0023
# 1963-04-30  0.0451 -0.037328  0.000190  0.005077  0.0025
# 1963-05-31  0.0176  0.021518  0.017593  0.002848  0.0024
# ...            ...       ...       ...       ...     ...
# 2016-08-31  0.0050  0.025444  0.018547 -0.049411  0.0002
# 2016-09-30  0.0025  0.013134 -0.009430 -0.021728  0.0002
# 2016-10-31 -0.0202 -0.018153  0.032443  0.020009  0.0002
# 2016-11-30  0.0486  0.060455  0.048981 -0.076985  0.0001
# 2016-12-31  0.0182  0.016927  0.004534  0.004859  0.0003
#
# [648 rows x 5 columns]

# %% [markdown]
# ### Examples

# %%
import getfactormodels as gfm # easier to type

#by default, frequency is 'monthly'
data = gfm.get_factors(model="liq")

print(data)
# Out:
# INFO:getfactormodels.models.liquidity.LiquidityFactors:Downloading data from: https://finance.wharton.upenn.edu/~stambaug/liq_data_1962_2024.txt
#              AGG_LIQ  INNOV_LIQ  TRADED_LIQ
# date
# 1962-08-31 -0.017537   0.004260 -999.000000
# 1962-09-30 -0.004075   0.011763 -999.000000
# 1962-10-31 -0.104212  -0.074041 -999.000000
# 1962-11-30 -0.019742   0.028183 -999.000000
# 1962-12-31 -0.005089   0.012929 -999.000000
# ...              ...        ...         ...
# 2024-08-31 -0.027287   0.022926   -0.036763
# 2024-09-30 -0.066454  -0.008930   -0.029484
# 2024-10-31  0.096943   0.173471    0.028040
# 2024-11-30 -0.026715  -0.041415    0.008552
# 2024-12-31 -0.061660  -0.022422    0.040918
#
# [749 rows x 3 columns]

# %%
#retrieve data from start_date to end_date:
data = gfm.get_factors(model='icr', frequency='d', start_date='2000-01-01', end_date='2009-12-31')
print(data)
# Out:
# INFO:getfactormodels.models.icr.ICRFactors:Downloading data from: https://zhiguohe.net/wp-content/uploads/2025/07/He_Kelly_Manela_Factors_daily_250627.csv
#             IC_RATIO  IC_RISK_FACTOR  INT_VW_ROI  INT_LEV_RATIO_SQ
# date
# 1999-05-03  0.227866             NaN    0.012224         19.259272
# 1999-05-04  0.224047             NaN   -0.023277         19.921465
# 1999-05-05  0.222895             NaN   -0.005300         20.127913
# 1999-05-06  0.219804             NaN   -0.016812         20.698090
# 1999-05-07  0.221466             NaN    0.010662         20.388566
# ...              ...             ...         ...               ...
# 1999-12-27  0.175941             NaN   -0.004593         32.304643
# 1999-12-28  0.176729             NaN    0.006785         32.017232
# 1999-12-29  0.177033             NaN    0.002007         31.907388
# 1999-12-30  0.179016             NaN    0.013955         31.204540
# 1999-12-31  0.146515             NaN    0.001774         46.583727
#
# ...

# %%
#retrieve all data since start_date
data = gfm.get_factors(model="dhs", start_date='2003-01-01')

print(data)
# Out:
# INFO:getfactormodels.models.dhs.DHSFactors:Downloading data from: https://docs.google.com/spreadsheets/d/1VwQcowFb5c0x3-0sQVf1RfIcUpetHK46/export?format=xlsx
# INFO:getfactormodels.models.fama_french.FamaFrenchFactors:Downloading data from: https://mba.tuck.dartmouth.edu/pages/faculty/ken.french/ftp/F-F_Research_Data_Factors_CSV.zip
#             Mkt-RF      PEAD       FIN      RF
# date
# 2003-01-31 -0.0257  0.020107 -0.004556  0.0010
# 2003-02-28 -0.0188 -0.003767  0.008632  0.0009
# 2003-03-31  0.0109  0.022451 -0.025939  0.0010
# 2003-04-30  0.0818 -0.023022 -0.046364  0.0010
# 2003-05-31  0.0605 -0.003711 -0.059381  0.0009
# ...            ...       ...       ...     ...
# 2023-08-31 -0.0236  0.024980  0.029629  0.0045
# 2023-09-30 -0.0523  0.022057  0.022191  0.0043
# 2023-10-31 -0.0315  0.015232  0.035333  0.0047
# 2023-11-30  0.0888 -0.033784 -0.052750  0.0044
# 2023-12-31  0.0485  0.011399 -0.075283  0.0043
#
# [252 rows x 4 columns]

# %%
# Get all data up until end_date
data = gfm.get_factors(model="misp", end_date='1992-12-31')

print(data)
# Out:
# INFO:getfactormodels.models.mispricing.MispricingFactors:Downloading data from: https://finance.wharton.upenn.edu/~stambaug/M4.csv
#             Mkt-RF    SMB_SY      MGMT      PERF      RF
# date
# 1963-01-31  0.0493  0.024818  0.021349 -0.022751  0.0025
# 1963-02-28 -0.0238  0.018096  0.010961  0.000874  0.0023
# 1963-03-31  0.0308 -0.008183  0.005890  0.023281  0.0023
# 1963-04-30  0.0451 -0.037328  0.000190  0.005077  0.0025
# 1963-05-31  0.0176  0.021518  0.017593  0.002848  0.0024
# ...            ...       ...       ...       ...     ...
# 1992-08-31 -0.0238  0.001376  0.005729  0.039331  0.0026
# 1992-09-30  0.0119 -0.000714 -0.001345  0.012848  0.0026
# 1992-10-31  0.0102  0.018055 -0.031258  0.021084  0.0023
# 1992-11-30  0.0413  0.022763 -0.037026 -0.010526  0.0023
# 1992-12-31  0.0153  0.012910  0.009303 -0.009658  0.0028
#
# [360 rows x 5 columns]

# %%
#save to file
gfm.get_factors(model="q", frequency='y', output='~/yes.csv')
# Out:
# INFO:getfactormodels.models.q_factors.QFactors:Downloading data from: https://global-q.org/uploads/1/2/2/6/122679606/q5_factors_annual_2024.csv
# File exists: yes.csv - overwriting...
# File saved to: /home/x512/yes.csv
#               Mkt-RF      R_ME      R_IA     R_ROE      R_EG        RF
# date
# 1967-12-31  0.245858  0.405993 -0.120498  0.202300 -0.036569  0.041474
# 1968-12-31  0.088195  0.245152  0.150566 -0.020500  0.117763  0.052942
# 1969-12-31 -0.175396 -0.118015  0.005610  0.151654  0.127564  0.065912
# 1970-12-31 -0.064274 -0.083673  0.234743 -0.004610  0.192725  0.063829
# 1971-12-31  0.118256  0.057711  0.011773  0.119847  0.056597  0.043172
# 1972-12-31  0.129340 -0.099505  0.045445  0.051291  0.148717  0.038912
# 1973-12-31 -0.262550 -0.175679  0.080119  0.010975  0.173093  0.070586
# 1974-12-31 -0.358234  0.046005  0.191786  0.116948  0.200955  0.080781
# 1975-12-31  0.324222  0.171808  0.075107 -0.059409  0.112375  0.058210
# ...

# %% [markdown]
# Data is cached (for 1 day by default), so running get_factors() twice for any model/frequency combination won't redownload the data:

# %%
bs = gfm.get_factors(model='bs', frequency='m', start_date='1991-01-01', end_date='1999-12-31')
#TODO: warn user if start date is before data start date
print(bs)
# Out:
# INFO:getfactormodels.models.q_factors.QFactors:Downloading data from: https://global-q.org/uploads/1/2/2/6/122679606/q5_factors_monthly_2024.csv
# INFO:getfactormodels.utils.http_client:Connecting: https://global-q.org/uploads/1...
#   - Getting q factors...
# INFO:getfactormodels.utils.http_client:36487 bytes cached.
# INFO:getfactormodels.models.fama_french.FamaFrenchFactors:Downloading data from: https://mba.tuck.dartmouth.edu/pages/faculty/ken.french/ftp/F-F_Research_Data_5_Factors_2x3_CSV.zip
# INFO:getfactormodels.utils.http_client:Connecting: https://mba.tuck.dartmouth.edu...
#   - Getting Fama-French factors...
# INFO:getfactormodels.utils.http_client:11768 bytes cached.
# INFO:getfactormodels.models.hml_devil.HMLDevilFactors:Downloading data from: https://www.aqr.com/-/media/AQR/Documents/Insights//Data-Sets/The-Devil-in-HMLs-Details-Factors-monthly.xlsx
#   - Getting HML_Devil factor (this can take a while,please be patient)...
# ...

# %%
bs = gfm.get_factors(model='bs', frequency='m', start_date='1996-06-30', end_date='2002-12-31')
print(bs.head(3))
# Out:
# INFO:getfactormodels.models.q_factors.QFactors:Downloading data from: https://global-q.org/uploads/1/2/2/6/122679606/q5_factors_monthly_2024.csv
# INFO:getfactormodels.models.fama_french.FamaFrenchFactors:Downloading data from: https://mba.tuck.dartmouth.edu/pages/faculty/ken.french/ftp/F-F_Research_Data_5_Factors_2x3_CSV.zip
# INFO:getfactormodels.models.hml_devil.HMLDevilFactors:Downloading data from: https://www.aqr.com/-/media/AQR/Documents/Insights//Data-Sets/The-Devil-in-HMLs-Details-Factors-monthly.xlsx
#   - Getting q factors...
#   - Getting Fama-French factors...
#   - Getting HML_Devil factor (this can take a while,please be patient)...
#                 R_IA     R_ROE  Mkt-RF     SMB     UMD  HML_Devil        RF
# date
# 1996-06-30  0.017379  0.008663 -0.0113 -0.0367  0.0102   0.019262  0.004200
# 1996-07-31  0.020166  0.024151 -0.0596 -0.0378 -0.0015   0.028871  0.004200
# 1996-08-31 -0.018517  0.001317  0.0277  0.0258 -0.0002  -0.025955  0.004317

# %% [markdown]
# ### CLI Examples

# %%
# %%bash
# # Quarterly classic q-factor model:
# getfactormodels -m q4 -f q

# %%
# %%bash
# #Barillas Shanken 6 Factor model
# getfactormodels -m bs6 -f m --start 2005-01-01 --end 2005-06-30

# %%
# %%bash
# #Barillas Shanken 6 Factor model (2nd run, with cache)
# getfactormodels -m bs6 -f m -s 2005-06-01 -e 2009-31-12

# %%
# %%bash
# # Weekly q-factor model:
# getfactormodels -m q -f w
#
# # Quarterly ICR
# getfactormodels -m icr -f q
#
# # Monthly liquidity
# getfactormodels -m liq -f m
#
# # Daily mispricing factors
# getfactormodels -m misp -f m
#
# # Annual Fama French 5 Factor model
# getfactormodels -m 5 -f y

# %% [markdown]
# ### CLASSES

# %%
import getfactormodels as gfm

q = gfm.QFactors(frequency='d', start_date='2020-01-01', end_date='2021-12-31')
q_df = q.download()

print(q_df)
# Out:
# INFO:getfactormodels.models.q_factors.QFactors:Downloading data from: https://global-q.org/uploads/1/2/2/6/122679606/q5_factors_daily_2024.csv
#               Mkt-RF      R_ME      R_IA     R_ROE      R_EG        RF
# date
# 2020-01-02  0.008625 -0.011246 -0.001730  0.000711  0.003401  0.000055
# 2020-01-03 -0.006729  0.002351 -0.001903 -0.001574  0.000749  0.000055
# 2020-01-06  0.003604 -0.003578 -0.004066 -0.004806  0.000426  0.000055
# 2020-01-07 -0.001922 -0.001384 -0.003215 -0.005125 -0.002243  0.000055
# 2020-01-08  0.004669 -0.001067 -0.001180  0.004533  0.006351  0.000055
# ...              ...       ...       ...       ...       ...       ...
# 2021-12-27  0.012243  0.001987  0.005071  0.016451  0.008696  0.000003
# 2021-12-28 -0.002717 -0.005467  0.004608  0.004991  0.000945  0.000003
# 2021-12-29  0.000597  0.001668 -0.000794  0.009230  0.004212  0.000003
# 2021-12-30 -0.001488 -0.001063 -0.005077 -0.008680 -0.003983  0.000003
# ...

# %%
from getfactormodels import FamaFrenchFactors

model = FamaFrenchFactors(model='3', frequency='d')  # TODO: fix float
data = model.download()
# Out:
# INFO:getfactormodels.models.fama_french.FamaFrenchFactors:Downloading data from: https://mba.tuck.dartmouth.edu/pages/faculty/ken.french/ftp/F-F_Research_Data_Factors_daily_CSV.zip

# %%
print(data)
# Out:
#             Mkt-RF    SMB_SY      MGMT      PERF      RF
# date
# 1963-01-31  0.0493  0.024818  0.021349 -0.022751  0.0025
# 1963-02-28 -0.0238  0.018096  0.010961  0.000874  0.0023
# 1963-03-31  0.0308 -0.008183  0.005890  0.023281  0.0023
# 1963-04-30  0.0451 -0.037328  0.000190  0.005077  0.0025
# 1963-05-31  0.0176  0.021518  0.017593  0.002848  0.0024
# ...            ...       ...       ...       ...     ...
# 1992-08-31 -0.0238  0.001376  0.005729  0.039331  0.0026
# 1992-09-30  0.0119 -0.000714 -0.001345  0.012848  0.0026
# 1992-10-31  0.0102  0.018055 -0.031258  0.021084  0.0023
# 1992-11-30  0.0413  0.022763 -0.037026 -0.010526  0.0023
# 1992-12-31  0.0153  0.012910  0.009303 -0.009658  0.0028
#
# [360 rows x 5 columns]

# %%
smb_factor = model.extract("SMB")
print(smb_factor)

# %%
from getfactormodels import QFactors
data = QFactors(frequency='d')

df = data.download()

print(df)
# Out:
# INFO:getfactormodels.models.q_factors.QFactors:Downloading data from: https://global-q.org/uploads/1/2/2/6/122679606/q5_factors_daily_2024.csv
#               Mkt-RF      R_ME      R_IA     R_ROE      R_EG        RF
# date
# 1967-01-03  0.000778  0.004891  0.001399 -0.007193 -0.008845  0.000187
# 1967-01-04  0.001667 -0.003507 -0.000575 -0.002073 -0.000410  0.000187
# 1967-01-05  0.012990  0.004395 -0.005716  0.000802 -0.003846  0.000187
# 1967-01-06  0.007230  0.006716  0.008990  0.003641  0.002269  0.000187
# 1967-01-09  0.008439  0.006340  0.000353  0.005007  0.002924  0.000187
# ...              ...       ...       ...       ...       ...       ...
# 2024-12-24  0.011142 -0.002781 -0.005338 -0.004244 -0.000198  0.000174
# 2024-12-26  0.000180  0.011101  0.004434 -0.007714 -0.005246  0.000174
# 2024-12-27 -0.011729 -0.002221  0.004214  0.001763 -0.000644  0.000174
# 2024-12-30 -0.010925  0.003764  0.002889  0.004383  0.001968  0.000174
# ...

# %%
from getfactormodels import MispricingFactors

data = MispricingFactors(start_date="2015-01-01", end_date="2019-12-31") # frequency = m by default

df = data.download()
# Out:
# INFO:getfactormodels.models.mispricing.MispricingFactors:Downloading data from: https://finance.wharton.upenn.edu/~stambaug/M4.csv

# %%
print(df)
# Out:
#             Mkt-RF    SMB_SY      MGMT      PERF      RF
# date
# 2015-01-31 -0.0311 -0.027071 -0.022678  0.050616  0.0000
# 2015-02-28  0.0613  0.024455 -0.012387 -0.030026  0.0000
# 2015-03-31 -0.0112  0.021447 -0.019166  0.005964  0.0000
# 2015-04-30  0.0059 -0.025993  0.008178 -0.041800  0.0000
# 2015-05-31  0.0136  0.014129 -0.004976  0.010770  0.0000
# 2015-06-30 -0.0153  0.030147 -0.007183  0.003874  0.0000
# 2015-07-31  0.0154 -0.033970  0.004192  0.070582  0.0000
# 2015-08-31 -0.0604 -0.006840  0.007253  0.013269  0.0000
# 2015-09-30 -0.0308 -0.022846  0.037284  0.079026  0.0000
# 2015-10-31  0.0775 -0.022708  0.024020 -0.006116  0.0000
# 2015-11-30  0.0056  0.028851 -0.002080 -0.009791  0.0000
# 2015-12-31 -0.0217 -0.031398  0.017458  0.047069  0.0001
# 2016-01-31 -0.0577 -0.031992  0.031514  0.110203  0.0001
# 2016-02-29 -0.0007 -0.000619  0.014589  0.023668  0.0002
# 2016-03-31  0.0696  0.000261 -0.009720 -0.049964  0.0002
# ...

# %%
# Extract factors

# %% [markdown]
# ### 3. CLI Examples
#
# - Output working. Date inputs need improving, use YYYY-MM-DD explicitly

# %%
# %%bash
# getfactormodels -m 4 -f d -s 2000-01-01 -e 2001-05-01 -o "~/output_file.csv"
# Out:
# INFO:getfactormodels.models.fama_french.FamaFrenchFactors:Downloading data from: https://mba.tuck.dartmouth.edu/pages/faculty/ken.french/ftp/F-F_Research_Data_Factors_daily_CSV.zip
# File exists: 4_d_2000-01-01_2001-05-01.csv - overwriting...
# File saved to: /home/x512/4_d_2000-01-01_2001-05-01.csv
#
#             Mkt-RF     SMB     HML      RF     MOM
# date
# 2000-01-03 -0.0071  0.0055 -0.0131  0.0002 -0.0006
# 2000-01-04 -0.0406 -0.0002  0.0207  0.0002 -0.0191
# 2000-01-05 -0.0009  0.0031 -0.0005  0.0002 -0.0049
# 2000-01-06 -0.0074 -0.0043  0.0124  0.0002 -0.0149
# 2000-01-07  0.0321 -0.0040 -0.0157  0.0002  0.0059
# ...            ...     ...     ...     ...     ...
# 2001-04-25  0.0168  0.0071 -0.0079  0.0002 -0.0037
# 2001-04-26  0.0045  0.0018  0.0043  0.0002  0.0081
# 2001-04-27  0.0147 -0.0015 -0.0018  0.0002 -0.0076
# 2001-04-30  0.0003  0.0066 -0.0042  0.0002 -0.0115
# 2001-05-01  0.0137  0.0009 -0.0088  0.0001 -0.0120
#
# [335 rows x 5 columns]

# %%
# %%bash
# getfactormodels -m 6 -f d -s 1964-01-01
# Out:
# INFO:getfactormodels.models.fama_french.FamaFrenchFactors:Downloading data from: https://mba.tuck.dartmouth.edu/pages/faculty/ken.french/ftp/F-F_Research_Data_5_Factors_2x3_daily_CSV.zip
# File exists: 6_d_1964-01-01_None.csv - overwriting...
# File saved to: /home/x512/6_d_1964-01-01_None.csv
#
#             Mkt-RF     SMB     HML     RMW     CMA      RF     UMD
# date
# 1964-01-02  0.0060  0.0063  0.0059 -0.0036  0.0002  0.0001 -0.0011
# 1964-01-03  0.0017  0.0022  0.0036 -0.0031  0.0044  0.0001 -0.0037
# 1964-01-06  0.0024  0.0011  0.0002 -0.0024  0.0041  0.0001 -0.0016
# 1964-01-07  0.0007  0.0022  0.0075 -0.0044  0.0091  0.0001 -0.0039
# 1964-01-08  0.0032  0.0003 -0.0014  0.0023 -0.0004  0.0001  0.0000
# ...            ...     ...     ...     ...     ...     ...     ...
# 2025-10-27  0.0117 -0.0081 -0.0121 -0.0023 -0.0119  0.0002  0.0047
# 2025-10-28  0.0018 -0.0034 -0.0061  0.0063 -0.0101  0.0002  0.0080
# 2025-10-29 -0.0009 -0.0098 -0.0081  0.0030 -0.0137  0.0002  0.0194
# ...

# %%
# %%bash
# # Quarterly classic q-factor model:
# getfactormodels -m q4 -f q
# Out:
# INFO:getfactormodels.models.q_factors.QFactors:Downloading data from: https://global-q.org/uploads/1/2/2/6/122679606/q5_factors_quarterly_2024.csv
# File exists: q4_q_None_None.csv - overwriting...
# File saved to: /home/x512/q4_q_None_None.csv
#
#               Mkt-RF      R_ME      R_IA     R_ROE        RF
# date
# 1967-03-31  0.134805  0.114866 -0.053626  0.084400  0.011406
# 1967-06-30  0.018500  0.087544 -0.026375  0.021278  0.009172
# 1967-09-30  0.068962  0.055625  0.040412 -0.006436  0.009601
# 1967-12-31  0.002605  0.052229 -0.052616  0.048551  0.010668
# 1968-03-31 -0.074902  0.013478  0.062313 -0.014532  0.011806
# ...              ...       ...       ...       ...       ...
# 2023-12-31  0.106333  0.014610 -0.027382 -0.011380  0.013465
# 2024-03-31  0.088848 -0.048872 -0.012363  0.034865  0.013167
# 2024-06-30  0.022145 -0.051355 -0.025798  0.084276  0.013464
# 2024-09-30  0.046601  0.020398  0.017324  0.025571  0.013812
# ...

# %%
# %%bash
# #Barillas Shanken 6 Factor model
# getfactormodels -m bs6 -f m
# Out:
# INFO:getfactormodels.models.q_factors.QFactors:Downloading data from: https://global-q.org/uploads/1/2/2/6/122679606/q5_factors_monthly_2024.csv
# INFO:getfactormodels.models.fama_french.FamaFrenchFactors:Downloading data from: https://mba.tuck.dartmouth.edu/pages/faculty/ken.french/ftp/F-F_Research_Data_5_Factors_2x3_CSV.zip
# INFO:getfactormodels.models.hml_devil.HMLDevilFactors:Downloading data from: https://www.aqr.com/-/media/AQR/Documents/Insights//Data-Sets/The-Devil-in-HMLs-Details-Factors-monthly.xlsx
#   - Getting q factors...
#   - Getting Fama-French factors...
#   - Getting HML_Devil factor (this can take a while,please be patient)...
# File exists: bs6_m_None_None.csv - overwriting...
# File saved to: /home/x512/bs6_m_None_None.csv
#
#                 R_IA     R_ROE  Mkt-RF     SMB     UMD  HML_Devil        RF
# date
# 1990-07-31  0.040124  0.025575 -0.0190 -0.0315  0.0604  -0.017966  0.006450
# ...

# %%
# %%bash
# #Barillas Shanken 6 Factor model -- 2nd run, with cache
# getfactormodels -m bs6 -f m
# Out:
# INFO:getfactormodels.models.q_factors.QFactors:Downloading data from: https://global-q.org/uploads/1/2/2/6/122679606/q5_factors_monthly_2024.csv
# INFO:getfactormodels.models.fama_french.FamaFrenchFactors:Downloading data from: https://mba.tuck.dartmouth.edu/pages/faculty/ken.french/ftp/F-F_Research_Data_5_Factors_2x3_CSV.zip
# INFO:getfactormodels.models.hml_devil.HMLDevilFactors:Downloading data from: https://www.aqr.com/-/media/AQR/Documents/Insights//Data-Sets/The-Devil-in-HMLs-Details-Factors-monthly.xlsx
#   - Getting q factors...
#   - Getting Fama-French factors...
#   - Getting HML_Devil factor (this can take a while,please be patient)...
# File exists: bs6_m_None_None.csv - overwriting...
# File saved to: /home/x512/bs6_m_None_None.csv
#
#                 R_IA     R_ROE  Mkt-RF     SMB     UMD  HML_Devil        RF
# date
# 1990-07-31  0.040124  0.025575 -0.0190 -0.0315  0.0604  -0.017966  0.006450
# ...

# %%
# %%bash
# # Weekly q-factor model:
# getfactormodels -m q -f w
#
# # Quarterly ICR
# getfactormodels -m icr -f q
#
# # Monthly liquidity
# getfactormodels -m liq -f m
#
# # Daily mispricing factors
# getfactormodels -m misp -f m
#
# # Annual Fama French 5 Factor model
# getfactormodels -m 5 -f y
# Out:
# INFO:getfactormodels.models.q_factors.QFactors:Downloading data from: https://global-q.org/uploads/1/2/2/6/122679606/q5_factors_weekly_2024.csv
# File exists: q_w_None_None.csv - overwriting...
# File saved to: /home/x512/q_w_None_None.csv
#
#               Mkt-RF      R_ME      R_IA     R_ROE      R_EG        RF
# date
# 1967-01-06  0.022823  0.012668  0.004269 -0.005084 -0.011172  0.000747
# 1967-01-13  0.029326  0.014232 -0.003834  0.007606  0.008189  0.000934
# 1967-01-20  0.018872  0.012531 -0.016048  0.003933 -0.011684  0.000934
# 1967-01-27  0.003518  0.017395 -0.015365  0.012813 -0.002194  0.000934
# 1967-02-03  0.013707  0.009202  0.005815  0.002693 -0.000917  0.000964
# ...              ...       ...       ...       ...       ...       ...
# 2024-11-29  0.009737  0.009487  0.000313 -0.005808 -0.013024  0.000790
# 2024-12-06  0.010414 -0.021554 -0.015049 -0.006467  0.021841  0.000871
# 2024-12-13 -0.009233 -0.022040 -0.009624 -0.015211  0.025542  0.000871
# ...

# %% [markdown]
# #### New extract

# %%
from getfactormodels import QFactors

# %%
model = QFactors(classic=True, start_date='2000-02-02')

# %%
model.download()
# Out:
# INFO:getfactormodels.models.q_factors.QFactors:Downloading data from: https://global-q.org/uploads/1/2/2/6/122679606/q5_factors_monthly_2024.csv
#               Mkt-RF      R_ME      R_IA     R_ROE        RF
# date
# 2000-02-29  0.024578  0.221445 -0.053931 -0.075531  0.004295
# 2000-03-31  0.052266 -0.144060  0.018350  0.076712  0.004377
# 2000-04-30 -0.063780 -0.048612  0.037871  0.087108  0.004595
# 2000-05-31 -0.043692 -0.045950  0.005085  0.000196  0.004782
# 2000-06-30  0.046557  0.102581 -0.033837 -0.047887  0.003744
# ...              ...       ...       ...       ...       ...
# 2024-08-31  0.016518 -0.040817  0.004687  0.018369  0.004419
# 2024-09-30  0.016806 -0.011967 -0.000010  0.007408  0.004619
# 2024-10-31 -0.009701 -0.011261 -0.011676 -0.002314  0.003907
# 2024-11-30  0.065002  0.043985 -0.049491 -0.015370  0.003955
# 2024-12-31 -0.031637 -0.051564 -0.003684 -0.021442  0.003663
#
# [299 rows x 5 columns]

# %%
model.extract("R_IA")
# Out:
# date
# 2000-02-29   -0.053931
# 2000-03-31    0.018350
# 2000-04-30    0.037871
# 2000-05-31    0.005085
# 2000-06-30   -0.033837
#                 ...
# 2024-08-31    0.004687
# 2024-09-30   -0.000010
# 2024-10-31   -0.011676
# 2024-11-30   -0.049491
# 2024-12-31   -0.003684
# Name: R_IA, Length: 299, dtype: float64

# %%
data = QFactors(end_date='2001-12-31', output_file="~/yoooooo.csv").download()
# Out:
# INFO:getfactormodels.models.q_factors.QFactors:Downloading data from: https://global-q.org/uploads/1/2/2/6/122679606/q5_factors_monthly_2024.csv
# File exists: yoooooo.csv - overwriting...
# File saved to: /home/x512/yoooooo.csv

# %%
factor = QFactors(frequency='m', start_date='2010-01-01').extract("R_IA")
# Out:
# INFO:getfactormodels.models.q_factors.QFactors:Downloading data from: https://global-q.org/uploads/1/2/2/6/122679606/q5_factors_monthly_2024.csv
# File exists: yoooooo.csv - overwriting...
# File saved to: /home/x512/yoooooo.csv

# %%
factor = QFactors(frequency='d').extract("R_ROE")
# Out:
# INFO:getfactormodels.models.q_factors.QFactors:Downloading data from: https://global-q.org/uploads/1/2/2/6/122679606/q5_factors_quarterly_2024.csv
# File exists: yoooooo.csv - overwriting...
# File saved to: /home/x512/yoooooo.csv

# %%
print(factor)
# Out:
# date
# 1967-03-31    0.084400
# 1967-06-30    0.021278
# 1967-09-30   -0.006436
# 1967-12-31    0.048551
# 1968-03-31   -0.014532
#                 ...
# 2000-12-31    0.210630
# 2001-03-31   -0.006186
# 2001-06-30   -0.035278
# 2001-09-30    0.153720
# 2001-12-31   -0.134794
# Name: R_ROE, Length: 140, dtype: float64

# %% [markdown]
# Quick notes:
#
# - date validation isn't working correctly in CLI. Fixing now. Use YYYY-MM-DD input.
#
# Can't do:

# %%
## Can't do:
#df = QFactors(end_date='2001-12-31').download()
#df = df.extract("R_ROE") # This is a df

#df = QFactors(end_date='2001-12-31').download().extract("R_ROE")
# Out:
# INFO:getfactormodels.models.q_factors.QFactors:Downloading data from: https://global-q.org/uploads/1/2/2/6/122679606/q5_factors_monthly_2024.csv
# File exists: yoooooo.csv - overwriting...
# File saved to: /home/x512/yoooooo.csv

# %% [markdown]
# Can do:

# %%
#store the model
m = QFactors(end_date='2001-12-31')

#Then download or extract from the model
data = m.download()

factor = m.extract("R_ROE")
print(factor)

another_factor = m.extract("R_IA")
print(another_factor)

# %%
print(data)
# Out:
#               Mkt-RF      R_ME      R_IA     R_ROE      R_EG        RF
# date
# 1967-01-31  0.081852  0.068122 -0.029263  0.018813 -0.025511  0.003927
# 1967-02-28  0.007557  0.016235 -0.002915  0.035399  0.021792  0.003743
# 1967-03-31  0.040169  0.019836 -0.016772  0.018417 -0.011192  0.003693
# 1967-04-30  0.038786 -0.006700 -0.028972  0.010253 -0.016371  0.003344
# 1967-05-31 -0.042807  0.027457  0.021864  0.005901  0.001191  0.003126
# ...              ...       ...       ...       ...       ...       ...
# 2001-08-31 -0.063871  0.023658  0.056559  0.042819  0.057144  0.002996
# 2001-09-30 -0.092292 -0.049266  0.028660  0.091887  0.057419  0.002730
# 2001-10-31  0.024886  0.034902 -0.029832 -0.043712 -0.005978  0.002154
# 2001-11-30  0.075282 -0.013907 -0.011371 -0.084905 -0.028900  0.001749
# 2001-12-31  0.016086  0.053196 -0.001655  0.005423 -0.020760  0.001484
#
# [420 rows x 6 columns]

# %%
print(factor)
# Out:
# date
# 1967-01-31    0.018813
# 1967-02-28    0.035399
# 1967-03-31    0.018417
# 1967-04-30    0.010253
# 1967-05-31    0.005901
#                 ...
# 2001-08-31    0.042819
# 2001-09-30    0.091887
# 2001-10-31   -0.043712
# 2001-11-30   -0.084905
# 2001-12-31    0.005423
# Name: R_ROE, Length: 420, dtype: float64

# %% [markdown]
# *Some notes until docs:*
#
# ## Models
#
# *A full list of models supported by the `get_factors` model param:*
#
# | ID | Factor Model |
# | :--- | :--- |
# | `3`, `ff3` | Fama-French 3 Factor model. |
# | `4`, `carhart`, `ff4` | Carhart 4 factor model (Fama-French 3-Factors with Momentum) |
# | `5`, `ff5` | Fama-French 5 factor model |
# | `6`, `ff6` | Fama-French 6 factor model |
# | `hmld`, `hml_devil` | ${HML}^{Devil}$ |
# | `dhs` | DHS Behavioural Factors |
# | `icr` | Intermediary Capital Ratio |
# | `mis` `sy`, `mispricing` | Stambaugh-Yuan's Mispricing Factors |
# | `liq`, `ps`, `liquidity` | Pastor-Stambaugh's Liquidity Factors |
# | `q`, `q5`<br>| The Augmented ${q}^{5}$ factor model. |
# | `q4`, `qclassic` | The $q$-factor model of Hou-Xue-Zhang (2015). |
# | `bs` | Barillas-Shanken 6 factor model. A composite model. |

# %% [markdown]
# ## Parameters
#
# #### `getfactormodels.get_factors()`
#
#
# *All models share these base params:*
#
# | Parameter | Description | Data Type | default |
# | :--- | :--- | :--- | :--- |
# |`model`|Model name, see id's above. |`str`|`None`|
# | `frequency` | The time frequency of the data, accepted values: `d`, `m`, `w`, `q`, `y`. | `str` | `m` |
# | `start_date` | The start date for the data retrieval. `YYYY-MM-DD` | `str`, `datetime` | `None` |
# | `end_date` | The end date for the data retrieval. `YYYY-MM-DD` | `str`, `datetime` | `None` |
# | `cache_ttl` | Time-to-live for cached data (how long to reuse downloaded data). | `int` | `86400` (1 day) |
# | `output_file` | Filepath to save data to | `str` | `None` |

# %% [markdown]
# #### Classes
# - `FamaFrenchFactors`
# - `CarhartFactors`
# - `QFactors`
# - `ICRFactors`
# - `DHSFactors`
# - `LiquidityFactors`
# - `MispricingFactors`
# - `HMLDevilFactors`
# - `BarillasShankenFactors`
#
# ##### Class params
# - All classes share these params:
#
#     | Param | Description | Type | default |
#     | :--- | :--- | :--- | :--- |
#     | `frequency` | The time frequency of the data, accepted values: `d`, `m`, `w`, `q`, `y`. | `str` | `m` |
#     | `start_date` | The start date for the data retrieval. `YYYY-MM-DD` | `str`, `datetime` | `None` |
#     | `end_date` | The end date for the data retrieval. `YYYY-MM-DD` | `str`, `datetime` | `None` |
#     | `cache_ttl` | Time-to-live for cached data (how long to reuse downloaded data). | `int` | `86400` (1 day) |
#     | `output_file` | Filepath to save data to | `str` | `None` |
# <br>
#
# - Some models have extra parameters:
#
#     | Class | Param | Description | Type | default |
#     | :--- | :---: | :--- | :---: | :--- |
#     | ``FamaFrenchFactors`` | `model` | Fama-French Factors specific model |  ``str``, ``int`` | `3` |
#     | ``QFactors`` | `classic` | If true returns the classic q-factor model. | `bool`  | `False` |

# %% [markdown]
# - `.download()` - download factor model data.
# - `.extract()` - extract a factor from a model.
# - `.data()` - access (or download if needed) stored data.

# %%
# getfactormodels: Copyright (c) S. Martin.

# %% [markdown]
# *Try it yourself!*
#
# [![Open in nbviewer](https://raw.githubusercontent.com/jupyter/design/main/logos/Badges/nbviewer_badge.svg)](https://nbviewer.org/github/x512/getfactormodels/blob/dev/example.ipynb)
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/x512/getfactormodels/blob/dev/example.ipynb)
